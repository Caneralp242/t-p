# %%
import cv2
import os
import matplotlib.pyplot as plt
import random
import pandas as pd
import python

# %%
from google.colab import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
import os
os.chdir("/gdrive/My Drive")
# !ls
# Out:
#  20170105_173517.jpg
# '2019 Takvimi.gsheet'
#  autoencodemiroglu.ipynb
#  autoencoder.ipynb
# 'Brain Tumor Segmentation.ipynb'
#  calışma_ortamı
# 'Copy of Linear Algebra 1.2.pdf'
#  darknet.zip
# 'EFT ile Para Girisi Bildirimi.html'
#  emiroğlu
#  GANs.ipynb
# 'Hesaba Para giris bildirimi.html'
# 'Kopyası - Explore example .gsheet'
#  mushrooms.csv
# 'New Zip.zip'
#  no
# 'Note 5 Oct 2020.pdf'
#  notebook83259cc8d8.ipynb
#  OpenCV
#  opencv.ipynb
# 'OSMANLI DEVLET ANLAYIŞI (1).pptx.gslides'
# 'OSMANLI DEVLET ANLAYIŞI.pptx'
# 'OSMANLI DEVLET ANLAYIŞI.pptx.gslides'
#  SPARK-ed.pdf
#  spot_model.ipynb
#  spot_weights
#  tıp
#  yekkaleli
#  yes

# %%
no="/gdrive/My Drive/no"
yes="/gdrive/My Drive/yes"
yes=os.listdir(yes)
no=os.listdir(no)

# %%
yest=[]
for i in range(len(yes)):
  yest.append("/gdrive/My Drive/yes/"+ yes[i])


nott=[]
for i in range(len(no)):
  nott.append("/gdrive/My Drive/no/"+ no[i])

# %%
nott
# Out:
# ['/gdrive/My Drive/no/1 no.jpeg',
#  '/gdrive/My Drive/no/11 no.jpg',
#  '/gdrive/My Drive/no/10 no.jpg',
#  '/gdrive/My Drive/no/18 no.jpg',
#  '/gdrive/My Drive/no/N16.jpg',
#  '/gdrive/My Drive/no/47 no.jpg',
#  '/gdrive/My Drive/no/N19.JPG',
#  '/gdrive/My Drive/no/43 no.jpg',
#  '/gdrive/My Drive/no/2 no.jpeg',
#  '/gdrive/My Drive/no/N17.jpg',
#  '/gdrive/My Drive/no/26 no.jpg',
#  '/gdrive/My Drive/no/9 no.jpg',
#  '/gdrive/My Drive/no/13 no.jpg',
#  '/gdrive/My Drive/no/41 no.jpg',
#  '/gdrive/My Drive/no/38 no.jpg',
#  '/gdrive/My Drive/no/14 no.jpg',
#  '/gdrive/My Drive/no/48 no.jpeg',
#  '/gdrive/My Drive/no/5 no.jpg',
#  '/gdrive/My Drive/no/40 no.jpg',
#  '/gdrive/My Drive/no/45 no.jpg',
#  '/gdrive/My Drive/no/24 no.jpg',
#  '/gdrive/My Drive/no/46 no.jpg',
#  '/gdrive/My Drive/no/44no.jpg',
#  '/gdrive/My Drive/no/49 no.jpg',
#  '/gdrive/My Drive/no/33 no.jpg',
#  '/gdrive/My Drive/no/28 no.jpg',
#  '/gdrive/My Drive/no/34 no.jpg',
#  '/gdrive/My Drive/no/N2.JPG',
#  '/gdrive/My Drive/no/50 no.jpg',
#  '/gdrive/My Drive/no/42 no.jpg',
#  '/gdrive/My Drive/no/N20.JPG',
#  '/gdrive/My Drive/no/N1.JPG',
#  '/gdrive/My Drive/no/N11.jpg',
#  '/gdrive/My Drive/no/3 no.jpg',
#  '/gdrive/My Drive/no/37 no.jpg',
#  '/gdrive/My Drive/no/12 no.jpg',
#  '/gdrive/My Drive/no/23 no.jpg',
#  '/gdrive/My Drive/no/19 no.jpg',
#  '/gdrive/My Drive/no/20 no.jpg',
#  '/gdrive/My Drive/no/8 no.jpg',
#  '/gdrive/My Drive/no/29 no.jpg',
#  '/gdrive/My Drive/no/7 no.jpg',
#  '/gdrive/My Drive/no/N22.JPG',
#  '/gdrive/My Drive/no/N21.jpg',
#  '/gdrive/My Drive/no/36 no.jpg',
#  '/gdrive/My Drive/no/21 no.jpg',
#  '/gdrive/My Drive/no/31 no.jpg',
#  '/gdrive/My Drive/no/35 no.jpg',
#  '/gdrive/My Drive/no/22 no.jpg',
#  '/gdrive/My Drive/no/N15.jpg',
#  '/gdrive/My Drive/no/27 no.jpg',
#  '/gdrive/My Drive/no/17 no.jpg',
#  '/gdrive/My Drive/no/6 no.jpg',
#  '/gdrive/My Drive/no/39 no.jpg',
#  '/gdrive/My Drive/no/4 no.jpg',
#  '/gdrive/My Drive/no/15 no.jpg',
#  '/gdrive/My Drive/no/30 no.jpg',
#  '/gdrive/My Drive/no/25 no.jpg',
#  '/gdrive/My Drive/no/32 no.jpg',
#  '/gdrive/My Drive/no/no 7.jpeg',
#  '/gdrive/My Drive/no/No17.jpg',
#  '/gdrive/My Drive/no/N26.JPG',
#  '/gdrive/My Drive/no/N6.jpg',
#  '/gdrive/My Drive/no/N3.jpg',
#  '/gdrive/My Drive/no/No22.jpg',
#  '/gdrive/My Drive/no/no 90.jpg',
#  '/gdrive/My Drive/no/No12.jpg',
#  '/gdrive/My Drive/no/No19.jpg',
#  '/gdrive/My Drive/no/no 3.jpg',
#  '/gdrive/My Drive/no/no 4.jpg',
#  '/gdrive/My Drive/no/no 92.jpg',
#  '/gdrive/My Drive/no/no 5.jpeg',
#  '/gdrive/My Drive/no/No13.jpg',
#  '/gdrive/My Drive/no/no.jpg',
#  '/gdrive/My Drive/no/no 1.jpg',
#  '/gdrive/My Drive/no/no 94.jpg',
#  '/gdrive/My Drive/no/N5.jpg',
#  '/gdrive/My Drive/no/no 923.jpg',
#  '/gdrive/My Drive/no/No16.jpg',
#  '/gdrive/My Drive/no/no 100.jpg',
#  '/gdrive/My Drive/no/No14.jpg',
#  '/gdrive/My Drive/no/no 8.jpg',
#  '/gdrive/My Drive/no/No11.jpg',
#  '/gdrive/My Drive/no/no 91.jpeg',
#  '/gdrive/My Drive/no/No20.jpg',
#  '/gdrive/My Drive/no/no 2.jpg',
#  '/gdrive/My Drive/no/no 98.jpg',
#  '/gdrive/My Drive/no/no 97.jpg',
#  '/gdrive/My Drive/no/no 95.jpg',
#  '/gdrive/My Drive/no/no 9.png',
#  '/gdrive/My Drive/no/No15.jpg',
#  '/gdrive/My Drive/no/no 6.jpg',
#  '/gdrive/My Drive/no/no 96.jpg',
#  '/gdrive/My Drive/no/no 99.jpg',
#  '/gdrive/My Drive/no/no 10.jpg',
#  '/gdrive/My Drive/no/no 89.jpg',
#  '/gdrive/My Drive/no/No18.jpg',
#  '/gdrive/My Drive/no/No21.jpg']

# %%
x_traint=yest[:130]+nott[:75]
x_testt=yest[130:]+nott[75:]

# %%
y_train=[]
for i in (x_traint):
  if i.startswith("/gdrive/My Drive/yes"):
    y_train.append(1)
  else:
    y_train.append(0)


y_test=[]
for i in x_testt:
  if i.startswith("/gdrive/My Drive/yes"):
    y_test.append(1)
  else:
    y_test.append(0)

# %%
train_list=[]
for i in (x_traint):

  imgO=cv2.imread(i)
  imgO=cv2.resize(imgO,(200,200))
  lab=cv2.cvtColor(imgO,cv2.COLOR_BGR2Lab)
  l,a,b=cv2.split(lab)
  clahe=cv2.createCLAHE(clipLimit=5.0,tileGridSize=((8,8)))
  cl=clahe.apply(l)
  limg=cv2.merge((cl,a,b))
  son=cv2.cvtColor(limg,cv2.COLOR_LAB2BGR)
  med_son=cv2.medianBlur(son,3)
  arka_plan=cv2.medianBlur(son,37)
  maske=cv2.addWeighted(med_son,1,arka_plan,-1,255)
  son_img=cv2.bitwise_and(maske,med_son)
  train_list.append(son_img)

# %%
plt.imshow(son)

# %%
len(train_list)
# Out:
# 205

# %%
test_list=[]
for i in (x_testt):

  imgO=cv2.imread(i)
  imgO=cv2.resize(imgO,(200,200))
  lab=cv2.cvtColor(imgO,cv2.COLOR_BGR2Lab)
  l,a,b=cv2.split(lab)
  clahe=cv2.createCLAHE(clipLimit=5.0,tileGridSize=((8,8)))
  cl=clahe.apply(l)
  limg=cv2.merge((cl,a,b))
  son=cv2.cvtColor(limg,cv2.COLOR_LAB2BGR)
  med_son=cv2.medianBlur(son,3)
  arka_plan=cv2.medianBlur(son,37)
  maske=cv2.addWeighted(med_son,1,arka_plan,-1,255)
  son_img=cv2.bitwise_and(maske,med_son)
  test_list.append(son_img)

# %%
plt.imshow(lab)

# %%
plt.imshow(son,cmap="gray")

# %%
plt.imshow(med_son,cmap="gray")

# %%
plt.imshow(arka_plan,cmap="gray")

# %%
plt.imshow(maske,cmap="gray")

# %%
plt.imshow(son_img,cmap="gray")

# %%
len(train_list)
# Out:
# 205

# %%
import numpy as np
x_train_last=np.array(train_list)
x_test_last=np.array(test_list)
y_train_last=np.array(y_train)
y_test_last=np.array(y_test)

# %%
len(x_train_last),type(x_train_last),len(y_train_last),type(y_train_last)
# Out:
# (205, numpy.ndarray, 205, numpy.ndarray)

# %%
from keras.callbacks import ReduceLROnPlateau
lr=ReduceLROnPlateau(monitor="val_accuracy",
                     pateince=3,
                     verbose=1,mode="auto",
                     factor=0.25,
                     min_lr=0.000001)

# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Dropout,MaxPool2D,Flatten
from keras.optimizers import Adam
model=Sequential()
model.add(Conv2D(filters=8,kernel_size=(5,5),padding="Same",activation="relu",input_shape=x_train_last.shape[1:]))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(filters=16,kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256,activation="relu"))
model.add(Dropout(0.25))
model.add(Dense(1,activation="sigmoid"))
optimizer=Adam(lr=0.001,beta_1=0.9,beta_2=0.99)
model.compile(optimizer=optimizer,loss="binary_crossentropy",metrics=["accuracy"])
history=model.fit(x_train_last,y_train_last,batch_size=10,epochs=100,validation_data=(x_test_last,y_test_last),callbacks=[lr])
# Out:
# Epoch 1/100
# 21/21 [==============================] - 9s 380ms/step - loss: 226.7744 - accuracy: 0.5629 - val_loss: 13.8972 - val_accuracy: 0.8125
# Epoch 42/100
# 21/21 [==============================] - 7s 334ms/step - loss: 4.5107e-14 - accuracy: 1.0000 - val_loss: 0.3026 - val_accuracy: 0.9792
# Epoch 43/100
# 21/21 [==============================] - 7s 330ms/step - loss: 2.1123e-09 - accuracy: 1.0000 - val_loss: 0.3028 - val_accuracy: 0.9792
# Epoch 44/100
# 21/21 [==============================] - 7s 329ms/step - loss: 3.3799e-11 - accuracy: 1.0000 - val_loss: 0.3028 - val_accuracy: 0.9792
# Epoch 45/100
# 21/21 [==============================] - 7s 329ms/step - loss: 7.3046e-10 - accuracy: 1.0000 - val_loss: 0.3028 - val_accuracy: 0.9792
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 46/100
# 21/21 [==============================] - 7s 330ms/step - loss: 9.0180e-13 - accuracy: 1.0000 - val_loss: 0.3028 - val_accuracy: 0.9792
# Epoch 47/100
# 21/21 [==============================] - 7s 332ms/step - loss: 5.2548e-11 - accuracy: 1.0000 - val_loss: 0.3028 - val_accuracy: 0.9792
# Epoch 48/100
# 21/21 [==============================] - 7s 331ms/step - loss: 4.4698e-13 - accuracy: 1.0000 - val_loss: 0.3028 - val_accuracy: 0.9792
# Epoch 49/100
# 21/21 [==============================] - 7s 334ms/step - loss: 3.4629e-07 - accuracy: 1.0000 - val_loss: 0.3028 - val_accuracy: 0.9792
# Epoch 50/100
# 21/21 [==============================] - 7s 337ms/step - loss: 3.4771e-11 - accuracy: 1.0000 - val_loss: 0.3031 - val_accuracy: 0.9792
# Epoch 51/100
# 21/21 [==============================] - 7s 339ms/step - loss: 1.6615e-05 - accuracy: 1.0000 - val_loss: 0.3049 - val_accuracy: 0.9792
# Epoch 52/100
# 21/21 [==============================] - 7s 339ms/step - loss: 2.1117e-05 - accuracy: 1.0000 - val_loss: 0.3094 - val_accuracy: 0.9792
# Epoch 53/100
# 21/21 [==============================] - 7s 335ms/step - loss: 1.2123e-10 - accuracy: 1.0000 - val_loss: 0.3113 - val_accuracy: 0.9792
# Epoch 54/100
# 21/21 [==============================] - 7s 334ms/step - loss: 5.4559e-07 - accuracy: 1.0000 - val_loss: 0.3115 - val_accuracy: 0.9792
# Epoch 55/100
# 21/21 [==============================] - 7s 336ms/step - loss: 2.0571e-14 - accuracy: 1.0000 - val_loss: 0.3116 - val_accuracy: 0.9792
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 56/100
# 21/21 [==============================] - 7s 335ms/step - loss: 1.4679e-12 - accuracy: 1.0000 - val_loss: 0.3116 - val_accuracy: 0.9792
# Epoch 57/100
# 21/21 [==============================] - 7s 329ms/step - loss: 6.9570e-11 - accuracy: 1.0000 - val_loss: 0.3116 - val_accuracy: 0.9792
# Epoch 58/100
# 21/21 [==============================] - 7s 332ms/step - loss: 1.0939e-09 - accuracy: 1.0000 - val_loss: 0.3116 - val_accuracy: 0.9792
# Epoch 59/100
# 21/21 [==============================] - 7s 332ms/step - loss: 8.5615e-06 - accuracy: 1.0000 - val_loss: 0.3118 - val_accuracy: 0.9792
# Epoch 60/100
# 21/21 [==============================] - 7s 337ms/step - loss: 4.2252e-05 - accuracy: 1.0000 - val_loss: 0.3131 - val_accuracy: 0.9792
# Epoch 61/100
# 21/21 [==============================] - 7s 339ms/step - loss: 5.9009e-13 - accuracy: 1.0000 - val_loss: 0.3133 - val_accuracy: 0.9792
# Epoch 62/100
# 21/21 [==============================] - 7s 340ms/step - loss: 1.4420e-14 - accuracy: 1.0000 - val_loss: 0.3134 - val_accuracy: 0.9792
# Epoch 63/100
# 21/21 [==============================] - 7s 339ms/step - loss: 6.0457e-11 - accuracy: 1.0000 - val_loss: 0.3134 - val_accuracy: 0.9792
# Epoch 64/100
# 21/21 [==============================] - 7s 343ms/step - loss: 2.7199e-05 - accuracy: 1.0000 - val_loss: 0.3142 - val_accuracy: 0.9792
# Epoch 65/100
# 21/21 [==============================] - 7s 341ms/step - loss: 4.7381e-10 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9792
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 66/100
# 21/21 [==============================] - 7s 341ms/step - loss: 1.4045e-12 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9792
# Epoch 67/100
# 21/21 [==============================] - 7s 338ms/step - loss: 4.4350e-08 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9792
# Epoch 68/100
# 21/21 [==============================] - 7s 334ms/step - loss: 1.0173e-06 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9792
# Epoch 69/100
# 21/21 [==============================] - 7s 339ms/step - loss: 1.1099e-12 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9792
# Epoch 70/100
# 21/21 [==============================] - 7s 338ms/step - loss: 7.7393e-09 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9792
# Epoch 71/100
# 21/21 [==============================] - 7s 344ms/step - loss: 8.9219e-12 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9792
# Epoch 72/100
# 21/21 [==============================] - 7s 346ms/step - loss: 1.6110e-10 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9792
# Epoch 73/100
# 21/21 [==============================] - 7s 334ms/step - loss: 2.1673e-11 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9792
# Epoch 74/100
# 21/21 [==============================] - 7s 329ms/step - loss: 9.6616e-10 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9792
# Epoch 75/100
# 21/21 [==============================] - 7s 331ms/step - loss: 3.4080e-08 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9792
# Epoch 76/100
# 21/21 [==============================] - 7s 330ms/step - loss: 1.5782e-04 - accuracy: 1.0000 - val_loss: 0.3118 - val_accuracy: 0.9792
# Epoch 77/100
# 21/21 [==============================] - 7s 330ms/step - loss: 3.6303e-10 - accuracy: 1.0000 - val_loss: 0.3115 - val_accuracy: 0.9792
# Epoch 78/100
# 21/21 [==============================] - 7s 333ms/step - loss: 1.9675e-08 - accuracy: 1.0000 - val_loss: 0.3114 - val_accuracy: 0.9792
# Epoch 79/100
# 21/21 [==============================] - 7s 329ms/step - loss: 1.5972e-09 - accuracy: 1.0000 - val_loss: 0.3114 - val_accuracy: 0.9792
# Epoch 80/100
# 21/21 [==============================] - 7s 331ms/step - loss: 1.6057e-11 - accuracy: 1.0000 - val_loss: 0.3114 - val_accuracy: 0.9792
# Epoch 81/100
# 21/21 [==============================] - 7s 336ms/step - loss: 4.5347e-07 - accuracy: 1.0000 - val_loss: 0.3115 - val_accuracy: 0.9792
# Epoch 82/100
# 21/21 [==============================] - 7s 335ms/step - loss: 2.9103e-10 - accuracy: 1.0000 - val_loss: 0.3115 - val_accuracy: 0.9792
# Epoch 83/100
# 21/21 [==============================] - 7s 337ms/step - loss: 5.2602e-10 - accuracy: 1.0000 - val_loss: 0.3115 - val_accuracy: 0.9792
# Epoch 84/100
# 21/21 [==============================] - 7s 336ms/step - loss: 3.8301e-12 - accuracy: 1.0000 - val_loss: 0.3115 - val_accuracy: 0.9792
# Epoch 85/100
# 21/21 [==============================] - 7s 335ms/step - loss: 1.5098e-10 - accuracy: 1.0000 - val_loss: 0.3115 - val_accuracy: 0.9792
# Epoch 86/100
# 21/21 [==============================] - 7s 337ms/step - loss: 2.6785e-06 - accuracy: 1.0000 - val_loss: 0.3116 - val_accuracy: 0.9792
# Epoch 87/100
# 21/21 [==============================] - 7s 334ms/step - loss: 3.3081e-10 - accuracy: 1.0000 - val_loss: 0.3116 - val_accuracy: 0.9792
# Epoch 88/100
# 21/21 [==============================] - 7s 337ms/step - loss: 1.7944e-10 - accuracy: 1.0000 - val_loss: 0.3116 - val_accuracy: 0.9792
# Epoch 89/100
# 21/21 [==============================] - 7s 336ms/step - loss: 2.3646e-05 - accuracy: 1.0000 - val_loss: 0.3132 - val_accuracy: 0.9792
# Epoch 90/100
# 21/21 [==============================] - 7s 340ms/step - loss: 2.7807e-11 - accuracy: 1.0000 - val_loss: 0.3134 - val_accuracy: 0.9792
# Epoch 91/100
# 21/21 [==============================] - 7s 335ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3169 - val_accuracy: 0.9792
# Epoch 92/100
# 21/21 [==============================] - 7s 336ms/step - loss: 8.6321e-08 - accuracy: 1.0000 - val_loss: 0.3186 - val_accuracy: 0.9792
# Epoch 93/100
# 21/21 [==============================] - 7s 330ms/step - loss: 4.4917e-08 - accuracy: 1.0000 - val_loss: 0.3189 - val_accuracy: 0.9792
# Epoch 94/100
# 21/21 [==============================] - 7s 334ms/step - loss: 1.2041e-10 - accuracy: 1.0000 - val_loss: 0.3189 - val_accuracy: 0.9792
# Epoch 95/100
# 21/21 [==============================] - 7s 341ms/step - loss: 1.8843e-06 - accuracy: 1.0000 - val_loss: 0.3194 - val_accuracy: 0.9792
# Epoch 96/100
# 21/21 [==============================] - 7s 342ms/step - loss: 1.6588e-11 - accuracy: 1.0000 - val_loss: 0.3207 - val_accuracy: 0.9792
# Epoch 97/100
# 21/21 [==============================] - 7s 337ms/step - loss: 5.8447e-11 - accuracy: 1.0000 - val_loss: 0.3209 - val_accuracy: 0.9792
# Epoch 98/100
# 21/21 [==============================] - 7s 338ms/step - loss: 8.2825e-09 - accuracy: 1.0000 - val_loss: 0.3209 - val_accuracy: 0.9792
# Epoch 99/100
# 21/21 [==============================] - 7s 336ms/step - loss: 3.8019e-07 - accuracy: 1.0000 - val_loss: 0.3211 - val_accuracy: 0.9792
# Epoch 100/100
# 21/21 [==============================] - 7s 333ms/step - loss: 8.0558e-08 - accuracy: 1.0000 - val_loss: 0.3212 - val_accuracy: 0.9792

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(history.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Train Accuracy = {}".format(np.round(acc[-1:],2)))
plt.plot(epochs_range, val_acc, label="Test Accuracy = {}".format(np.round(val_acc[-1:],2)))
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy = {}'.format(acc[-1:]))


plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Train Loss = {}".format(np.round(loss[-1:],5)))
plt.plot(epochs_range, val_loss, label="Test Loss = {}".format(np.round(val_loss[-1:],2)))
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')




plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns

predictions = model.predict(x_test_last)
predictions = [1 if x>0.5 else 0 for x in predictions]

accuracy = accuracy_score(y_test_last, predictions)
print('Test Accuracy = %.2f' % accuracy)

confusion_mtx = confusion_matrix(y_test_last, predictions)
sns.heatmap(confusion_mtx,annot=True)
plt.show()
# Out:
# Test Accuracy = 0.98

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns

predictions = model.predict(x_train_last)
predictions = [1 if x>0.5 else 0 for x in predictions]

accuracy = accuracy_score(y_train_last, predictions)
print('Test Accuracy = %.2f' % accuracy)

confusion_mtx = confusion_matrix(y_train_last, predictions)
sns.heatmap(confusion_mtx,annot=True)
plt.show()
# Out:
# Test Accuracy = 1.00
